# %%
## Let's import all packages first
import matplotlib.pyplot as pyplot
import pandas
import numpy as np
import functools

# %%
# Load CSV and display it
perceptions = pandas.read_csv("VOCS2016-2017-HOUSEHOLD/VOCS2016-2017-HOUSEHOLD_F1.csv")
perceptions
# Out:
#                      uqno  prov  Q21topiccrime  Q21bHowLong  Q2211Murder  \
# 0      160100720000002601     1              2            3            2
# 1      160100720000006301     1              2            2            2
# 2      160100720000010001     1              2            1            2
# 3      160101220000003001     1              2            3            2
# 4      160101220000006301     1              2            3            2
# 5      160101220000009601     1              2            3            2
# 6      160101220000016201     1              2            3            2
# 7      160101430000000901     1              2            3            2
# 8      160101430000003201     1              1            3            2
# 9      160101430000005501     1              2            3            2
# 10     160101430000007801     1              2            3            2
# 11     160101430000010101     1              2            3            2
# 12     160101430000012401     1              2            3            2
# 13     161100240000023401     1              2            3            2
# 14     161100240000032901     1              2            3            2
# 15     161100240000061401     1              2            3            2
# 16     161100350000006701     1              2            3            2
# 17     161100350000009701     1              2            3            2
# 18     161100520000003001     1              2            3            2
# 19     161100520000016401     1              2            3            2
# 20     161100520000023101     1              2            3            2
# 21     162100240000004801     1              2            3            2
# 22     162100240000011601     1              2            3            2
# 23     162100240000016701     1              2            3            2
# 24     162100360000002101     1              2            3            2
# 25     162100360000003401     1              2            3            2
# 26     162100360000004701     1              2            3            2
# 27     162100360000006001     1              2            3            1
# 28     162100360000007301     1              1            3            2
# 29     162100360000008601     1              2            3            2
# ...                   ...   ...            ...          ...          ...
# 21065  987105300000027101     9              1            3            2
# 21066  987105300000033701     9              1            3            2
# 21067  987105430000001101     9              2            3            2
# 21068  987105430000002801     9              1            3            2
# 21069  987105430000006201     9              2            2            2
# 21070  987105430000007901     9              2            3            2
# 21071  987105430000011301     9              1            3            2
# 21072  987105430000013001     9              1            3            2
# 21073  987105430000013002     9              1            3            2
# 21074  987105430000013003     9              2            1            2
# 21075  987105430000013004     9              1            3            2
# 21076  987105430000013005     9              2            1            2
# 21077  987105430000014701     9              2            3            2
# 21078  987105530000001701     9              1            3            2
# 21079  987105530000003501     9              1            3            2
# 21080  987105530000005301     9              1            3            2
# 21081  987105530000007101     9              1            3            2
# 21082  987105530000008901     9              2            3            2
# 21083  987105530000010701     9              1            3            2
# 21084  987105530000012501     9              1            3            2
# 21085  987105530000014301     9              1            3            2
# 21086  987105530000016101     9              1            3            2
# 21087  987105530000017901     9              2            3            2
# 21088  987106510000001501     9              1            3            2
# 21089  987106510000003001     9              1            3            2
# 21090  987106510000004501     9              2            3            2
# 21091  987106510000009001     9              2            3            1
# 21092  987106510000012001     9              2            3            2
# 21093  987106510000013501     9              2            3            2
# 21094  987106510000016501     9              2            3            2
#
#        Q2212StrRob  Q2213HomeRob  Q2214BussRob  Q2215Hijack  Q2216Assault  \
# 0                2             2             2            2             1
# 1                2             2             2            2             2
# 2                2             2             2            2             2
# 3                2             2             2            2             1
# 4                2             2             2            2             1
# 5                2             2             2            2             2
# 6                2             2             2            2             2
# 7                2             2             2            2             2
# 8                2             2             2            2             1
# 9                2             2             2            2             2
# 10               2             2             2            2             2
# 11               2             2             2            2             2
# 12               2             2             2            2             2
# 13               2             2             2            2             2
# 14               2             2             2            2             2
# 15               2             2             2            2             2
# 16               2             2             2            2             1
# 17               2             2             2            2             2
# 18               2             2             2            2             2
# 19               2             2             2            2             1
# 20               2             2             2            2             2
# 21               2             2             2            2             2
# 22               2             2             2            2             2
# 23               2             2             2            2             2
# 24               2             2             2            2             1
# 25               2             2             2            2             2
# 26               2             2             2            2             1
# 27               2             2             2            2             2
# 28               2             2             2            2             2
# 29               2             2             2            2             1
# ...            ...           ...           ...          ...           ...
# 21065            2             1             1            2             2
# 21066            1             1             1            2             2
# 21067            2             2             2            2             2
# 21068            2             2             2            2             2
# 21069            2             2             2            2             2
# 21070            2             2             2            2             2
# 21071            2             2             2            2             2
# 21072            2             2             2            2             2
# 21073            2             2             2            2             2
# 21074            2             2             2            2             2
# 21075            2             2             2            2             2
# 21076            2             2             2            2             2
# 21077            2             2             2            2             2
# 21078            2             2             1            2             2
# 21079            2             2             1            2             2
# 21080            2             1             1            2             2
# 21081            2             2             1            2             2
# 21082            2             2             2            2             2
# 21083            2             1             1            2             2
# 21084            2             2             1            2             2
# 21085            1             1             1            2             2
# 21086            2             2             1            2             2
# 21087            2             2             2            2             2
# 21088            2             1             2            2             2
# 21089            2             2             1            2             2
# 21090            2             2             2            2             2
# 21091            2             2             1            2             2
# 21092            2             2             1            2             2
# 21093            2             2             2            2             2
# 21094            2             2             1            2             2
#
#            ...       Q2012Who  Q2013Recovered  Q2014Secure  Q2015Measures  \
# 0          ...              9               9            9              9
# 1          ...              9               9            9              9
# 2          ...              9               9            9              9
# 3          ...              9               9            9              9
# 4          ...              9               9            9              9
# 5          ...              9               9            9              9
# 6          ...              9               9            9              9
# 7          ...              9               9            9              9
# 8          ...              9               9            9              9
# 9          ...              9               9            9              9
# 10         ...              9               9            9              9
# 11         ...              9               9            9              9
# 12         ...              9               9            9              9
# 13         ...              9               9            9              9
# 14         ...              9               9            9              9
# 15         ...              9               9            9              9
# 16         ...              9               9            9              9
# 17         ...              9               9            9              9
# 18         ...              9               9            9              9
# 19         ...              9               9            9              9
# 20         ...              9               9            9              9
# 21         ...              9               9            9              9
# 22         ...              9               9            9              9
# 23         ...              9               9            9              9
# 24         ...              9               9            9              9
# 25         ...              9               9            9              9
# 26         ...              9               9            9              9
# 27         ...              9               9            9              9
# 28         ...              9               9            9              9
# 29         ...              9               9            9              9
# ...        ...            ...             ...          ...            ...
# 21065      ...              9               9            9              9
# 21066      ...              9               9            9              9
# 21067      ...              9               9            9              9
# 21068      ...              9               9            9              9
# 21069      ...              9               9            9              9
# 21070      ...              9               9            9              9
# 21071      ...              9               9            9              9
# 21072      ...              9               9            9              9
# 21073      ...              9               9            9              9
# 21074      ...              9               9            9              9
# 21075      ...              9               9            9              9
# 21076      ...              9               9            9              9
# 21077      ...              9               9            9              9
# 21078      ...              9               9            9              9
# 21079      ...              9               9            9              9
# 21080      ...              9               9            9              9
# 21081      ...              9               9            9              9
# 21082      ...              9               9            9              9
# 21083      ...              9               9            9              9
# 21084      ...              9               9            9              9
# 21085      ...              9               9            9              9
# 21086      ...              9               9            9              9
# 21087      ...              9               9            9              9
# 21088      ...              9               9            9              9
# 21089      ...              9               9            9              9
# 21090      ...              9               9            9              9
# 21091      ...              9               9            9              9
# 21092      ...              9               9            9              9
# 21093      ...              9               9            9              9
# 21094      ...              9               9            9              9
#
#        Q2015Awareness  Q2015Gun  Q2015Weapon  Q2015Other  metro_code  \
# 0                   9         9            9           9           1
# 1                   9         9            9           9           1
# 2                   9         9            9           9           1
# 3                   9         9            9           9           1
# 4                   9         9            9           9           1
# 5                   9         9            9           9           1
# 6                   9         9            9           9           1
# 7                   9         9            9           9           1
# 8                   9         9            9           9           1
# 9                   9         9            9           9           1
# 10                  9         9            9           9           1
# 11                  9         9            9           9           1
# 12                  9         9            9           9           1
# 13                  9         9            9           9           1
# 14                  9         9            9           9           1
# 15                  9         9            9           9           1
# 16                  9         9            9           9           1
# 17                  9         9            9           9           1
# 18                  9         9            9           9           1
# 19                  9         9            9           9           1
# 20                  9         9            9           9           1
# 21                  9         9            9           9           1
# 22                  9         9            9           9           1
# 23                  9         9            9           9           1
# 24                  9         9            9           9           1
# 25                  9         9            9           9           1
# 26                  9         9            9           9           1
# 27                  9         9            9           9           1
# 28                  9         9            9           9           1
# 29                  9         9            9           9           1
# ...               ...       ...          ...         ...         ...
# 21065               9         9            9           9          17
# 21066               9         9            9           9          17
# 21067               9         9            9           9          17
# 21068               9         9            9           9          17
# 21069               9         9            9           9          17
# 21070               9         9            9           9          17
# 21071               9         9            9           9          17
# 21072               9         9            9           9          17
# 21073               9         9            9           9          17
# 21074               9         9            9           9          17
# 21075               9         9            9           9          17
# 21076               9         9            9           9          17
# 21077               9         9            9           9          17
# 21078               9         9            9           9          17
# 21079               9         9            9           9          17
# 21080               9         9            9           9          17
# 21081               9         9            9           9          17
# 21082               9         9            9           9          17
# 21083               9         9            9           9          17
# 21084               9         9            9           9          17
# 21085               9         9            9           9          17
# 21086               9         9            9           9          17
# 21087               9         9            9           9          17
# 21088               9         9            9           9          17
# 21089               9         9            9           9          17
# 21090               9         9            9           9          17
# 21091               9         9            9           9          17
# 21092               9         9            9           9          17
# 21093               9         9            9           9          17
# 21094               9         9            9           9          17
#
#        Unnamed: 674
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 21065           NaN
# 21066           NaN
# 21067           NaN
# 21068           NaN
# 21069           NaN
# 21070           NaN
# 21071           NaN
# 21072           NaN
# 21073           NaN
# 21074           NaN
# 21075           NaN
# 21076           NaN
# 21077           NaN
# 21078           NaN
# 21079           NaN
# 21080           NaN
# 21081           NaN
# 21082           NaN
# 21083           NaN
# 21084           NaN
# 21085           NaN
# 21086           NaN
# 21087           NaN
# 21088           NaN
# 21089           NaN
# 21090           NaN
# 21091           NaN
# 21092           NaN
# 21093           NaN
# 21094           NaN
#
# [21095 rows x 675 columns]

# %% [markdown]
# ## 21 095 records in total
#
# ### Let's see how many records we have for Gauteng...

# %%
# let's visualise CSV as table with +named colums+
provinces = perceptions["prov"].reset_index(name="provinces")
gauteng = perceptions[perceptions.prov == 7]
len(gauteng)
# Out:
# 5243

# %% [markdown]
# ### 5 243 records in total for Gauteng...
#
# #### Now let's count the records for the individual metros in Gauteng to double check

# %%
# Function to return the number of records in any given metro
def metro_count(region, metro_code):
    return len(region[region.metro_code == metro_code])

# Let's define a dictionary with Gauteng metro codes
gauteng_metros = {"GP - Non Metro": 12,
          "GP - Ekurhuleni": 13,
          "GP - City of Johannesburg": 14,
          "GP - City of Tshwane": 15}

# %%
# Now let's iterate through all the Gauteng codes and display the number of records for each metro
for metro in gauteng_metros:
    print(metro + ": " + str(metro_count(gauteng, gauteng_metros[metro])))
# Out:
# GP - Non Metro: 867
# GP - Ekurhuleni: 1389
# GP - City of Johannesburg: 1847
# GP - City of Tshwane: 1140

# %% [markdown]
# Everything corresponds with what's recorded in the documentation that came with the data.
#
# Now let's visualize the data...
#
# ## General thinking about crime
#
# In answer to the question:
#
# ### Has the topic of crime come up in any conversation you had with your family, friends or colleagues in the past two weeks?

# %%
# First, let's define a funtion to return the result to any other topic we might have
def freqCount(region, topic_code, response_code):
    return region.groupby(topic_code).size().reset_index(name = 'frequency')['frequency'][response_code]

# Let's define a few constants so our code can be clear
YES = 0
NO = 1
UNS = 2

# While we at it, let's define a function to format our percentage values for autopct in our pie charts
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val=int((pct*total/100.0)+0.5)
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %% [markdown]
# #### So now, to answer the question... "Has the topic of crime come up in any conversation you had with your family, friends or colleagues in the past two weeks?"...

# %%
code14 = perceptions[perceptions.metro_code==14]
freqCount(code14, "Q21topiccrime", UNS)
# Out:
# 17

# %% [markdown]
# ###### ...2 587 people answered "yes"

# %% [markdown]
# #### This means, in Gauteng, in answer to the question " Has the topic of crime come up in any conversation you had with your family, friends or colleagues in the past two weeks?", people that answered "yes" totalled 2 587, people that answered "no" totalled 2600, and people who's response was "unspecified" totalled 56.
#
# #### If we were to visualize this in a pie chart...

# %%
responses = [freqCount(gauteng, "Q21topiccrime", YES), freqCount(gauteng, "Q21topiccrime", NO), freqCount(gauteng, "Q21topiccrime", UNS)]
pyplot.pie(x = responses, labels=["Yes", "No", "Unspecified"], autopct=make_autopct(responses), shadow=True)
pyplot.title(" Has the topic of crime come up in any conversation you had with your family, friends or colleagues in the past two weeks?")
pyplot.show()

# %% [markdown]
# ### "Which crimes occur mostly in your area?"
# #### Let's see which one people answered yes to most...

# %%
occur_codes = ["Q2211Murder", "Q2212StrRob", "Q2213HomeRob", "Q2214BussRob", "Q2215Hijack", "Q2216Assault", "Q2217SexAssult", 
            "Q2218ChildAbuse", "Q2219Political", "Q22110Vigilante", "Q22111BagSnatch", 
            "Q22112Bicycle", "Q22113Car", "Q22114Burglary", "Q22115Crop", "Q22116Livestock", "Q22117WhiteCollar", "Q22118damage", 
            "Q22119IDtheft", "Q22120HumanTrafficking", "Q22121DrugTrafficking", "Q22122HateCrime", "Q22123Other"]
crime_labels = ["Murder", "Street Robbery", "Home Roberry", "Business Robbery","Vehicle Hijacking", "Assault", "Sexual Assault", 
          "Child Abuse", "Political Violence", "Vigilantism", "Bag Snatching", "Bicycle Theft", "Vehicle Theft", "House Breaking", 
          "Crop Theft", "Livestock Theft", "White Collar", "Damage", "Id theft", "Human Trafficking", "Drug Trafficking",
          "Hate Crime", "Other Crime"]

def multiFreqCount(region, occur_codes):
    crime_count = []
    for topic in occur_codes:
        crime_count.append(freqCount(gauteng, topic, 0))
        
    return crime_count

counts = multiFreqCount(gauteng, occur_codes)
counts.sort()
#crime_labels.sort()

counts
# Out:
# [48,
#  64,
#  73,
#  76,
#  104,
#  125,
#  147,
#  170,
#  182,
#  210,
#  329,
#  368,
#  388,
#  666,
#  720,
#  781,
#  796,
#  927,
#  977,
#  1176,
#  1893,
#  2475,
#  3022]

# %% [markdown]
# ### As can be seen on the graph...
# #### 1. Housebreaking/burglary occurs most, followed by
# #### 2. Street robbery
# #### 3. Home robbery
# #### 4. Bag snatching
# #### 5. Drug Trafficking

# %% [markdown]
# ### To answer the question "Which crimes are you most afraid of in your area?  (which ones did people answer yes to most?)"...
#
# #### Let's create a function to check all the counts, and return a list, sorted from highest count to lowest count

# %%
class CrimeData:
    """A simple crime-stats data class"""
    code = ""
    label = ""
    yes = 0
    no = 0
    uns = 0
    percentages = []
        
    def getPercentages(self):
        p = []
        total = (self.yes + self.no)
        p.append((self.yes/total*100))
        p.append((self.no/total*100))
        return p

    def __init__(self, region, topic, label):
        self.code = topic
        self.label = label
        self.yes = freqCount(region, self.code, YES)
        self.no = freqCount(region, self.code, NO)
        self.uns = freqCount(region, self.code, UNS)
        total = (self.yes + self.no)
        #self.percentages.append((self.yes/total*100))
        #self.percentages.append((self.no/total*100))
        #self.percentages.append((self.uns/total*100))
        percentages = getPercentages()

    def showInfo(self):
        fmt = "{:" + str(30-len(self.code)) + "}"
        returnString = "{:20}".format(self.label) + "[" + "{:}".format(self.code) + "]"
        returnString += fmt.format(" ") + "{:.2f}".format(self.percentages[0]) + "%"
        return  returnString
    
    def showAllInfo(stats):
        headings = "{:>9}".format("Label") + "{:>25}".format("Topic Code") + "{:>27}".format("Yes %")
        print(headings)
        for j in range(0, len(stats)):
            print("{:2}".format(str(j)) + ": " + stats[j].showInfo())

ASC = False
DEC = True

def sortStats(crimeData, prop, sortOrder):
    return sorted(crimeData, key=lambda occurence: prop, reverse=sortOrder)

crimeOccurenceStats = []

for i in range(0, len(occur_codes)):
    crimeOccurenceStats.append(CrimeData(gauteng, occur_codes[i], crime_labels[i]))

crimeOccurenceStats = sortStats(crimeOccurenceStats, CrimeData.yes, ASC)

#CrimeData.showAllInfo(crimeOccurenceStats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-351-583a8185c144> in <module>()
#      48
#      49 for i in range(0, len(occur_codes)):
# ---> 50     crimeOccurenceStats.append(CrimeData(gauteng, occur_codes[i], crime_labels[i]))
#      51
#      52 crimeOccurenceStats = sortStats(crimeOccurenceStats, CrimeData.yes, ASC)
#
# <ipython-input-351-583a8185c144> in __init__(self, region, topic, label)
#      25         #self.percentages.append((self.no/total*100))
#      26         #self.percentages.append((self.uns/total*100))
# ---> 27         percentages = Per()
#      28
#      29     def showInfo(self):
#
# NameError: name 'Per' is not defined
